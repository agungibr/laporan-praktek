# %% [markdown]
# <a href="https://colab.research.google.com/github/agungibr/laporan-praktek/blob/main/laprak1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Agung Malik Ibrahim"
nim = "2311110067"
alamat = "Larangan, Kec. Kembaran, Kab. Banyumas"
tanggal_lahir = "24 Desember 2004"
jenis_kelamin = "Laki-laki"
umur = "18 tahun"
no_hp = '081226035254'

print (nama)
print (nim)
print (alamat)
print (tanggal_lahir)
print (jenis_kelamin)
print (umur)
print (no_hp)
# Out:
# Agung Malik Ibrahim
# 2311110067
# Larangan, Kec. Kembaran, Kab. Banyumas
# 24 Desember 2004
# Laki-laki
# 18 tahun
# 081226035254

# %%
perkenalan = """
Setelah lulus dari Institut Teknologi Telkom Purwokerto
saya ingin menjadi data scientist.
Saya juga ingin bekerja di luar negri, seperti di
Australia ataupun New Zealand karena ingin menjelajahi
dan mengunjungi berbagai tempat yang keren dan indah
di seluruh dunia, serta mendapatkan gaji dollar.
"""

print (perkenalan)
# Out:
# Setelah lulus dari Institut Teknologi Telkom Purwokerto
# saya ingin menjadi data scientist.
# Saya juga ingin bekerja di luar negri, seperti di
# Australia ataupun New Zealand karena ingin menjelajahi
# dan mengunjungi berbagai tempat yang keren dan indah
# di seluruh dunia, serta mendapatkan gaji dollar.
