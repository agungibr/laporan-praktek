# %%
print (5)
type (5)

print (3.14)
type (3.14)

print (1+2j)
type (1+2j)

print([1, 2, 3, 4])
type ([1, 2, 3, 4])
print (['satu', 'dua', 'tiga', 'empat'])
type(['satu', 'dua', 'tiga', 'empat'])

print ({'nama' : 'Budi', 'umur' : 20})
type ({'nama' : 'Budi', 'umur' : 20})'nama' : 'Budi', 'umur' : 20
# Out:
# 5
# 3.14
# (1+2j)
# [1, 2, 3, 4]
# ['satu', 'dua', 'tiga', 'empat']
# {'nama': 'Budi', 'umur': 20}
# dict

# %%
Nama = "Arif"
Alamat = "Purwokerto, Jawa Tengah"
Pekerj44n = "Mahasiswa"

print (Nama)
print (Alamat)
print (Pekerj44n)
# Out:
# Arif
# Purwokerto, Jawa Tengah
# Mahasiswa

# %%
Banyak_baris = """
Saya
Berkuliah
di
Institut Teknologi Telkom Purwokerto
"""
print (Banyak_baris)
# Out:
# Saya
# Berkuliah
# di
# Institut Teknologi Telkom Purwokerto

# %%
for i in range (10):
    print ("Makan")
# Out:
# Makan
# Makan
# Makan
# Makan
# Makan
# Makan
# Makan
# Makan
# Makan
# Makan

# %%
print ("berdo'a di hari jum'at")
# Out:
# berdo'a di hari jum'at
